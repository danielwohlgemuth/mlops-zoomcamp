# %%
# !pip install mlflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mlflow==3.10.1 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (3.10.1)
# Requirement already satisfied: mlflow-skinny==3.10.1 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from mlflow==3.10.1) (3.10.1)
# Requirement already satisfied: mlflow-tracing==3.10.1 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from mlflow==3.10.1) (3.10.1)
# Requirement already satisfied: Flask-CORS<7 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from mlflow==3.10.1) (6.0.2)
# Requirement already satisfied: Flask<4 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from mlflow==3.10.1) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from mlflow==3.10.1) (1.18.4)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from mlflow==3.10.1) (46.0.3)
# Requirement already satisfied: docker<8,>=4.0.0 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from mlflow==3.10.1) (7.1.0)
# Requirement already satisfied: graphene<4 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from mlflow==3.10.1) (3.4.3)
# Requirement already satisfied: gunicorn<26 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from mlflow==3.10.1) (25.3.0)
# Requirement already satisfied: huey<3,>=2.5.4 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from mlflow==3.10.1) (2.6.0)
# Requirement already satisfied: matplotlib<4 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from mlflow==3.10.1) (3.10.6)
# Requirement already satisfied: numpy<3 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from mlflow==3.10.1) (2.3.5)
# Requirement already satisfied: pandas<3 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from mlflow==3.10.1) (2.3.3)
# Requirement already satisfied: pyarrow<24,>=4.0.0 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from mlflow==3.10.1) (21.0.0)
# Requirement already satisfied: scikit-learn<2 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from mlflow==3.10.1) (1.7.2)
# Requirement already satisfied: scipy<2 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from mlflow==3.10.1) (1.16.3)
# Requirement already satisfied: skops<1 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from mlflow==3.10.1) (0.13.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from mlflow==3.10.1) (2.0.43)
# Requirement already satisfied: cachetools<8,>=5.0.0 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.10.1->mlflow==3.10.1) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.10.1->mlflow==3.10.1) (8.2.1)
# Requirement already satisfied: cloudpickle<4 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.10.1->mlflow==3.10.1) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from mlflow-skinny==3.10.1->mlflow==3.10.1) (0.102.0)
# Requirement already satisfied: fastapi<1 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from mlflow-skinny==3.10.1->mlflow==3.10.1) (0.135.2)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.10.1->mlflow==3.10.1) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.10.1->mlflow==3.10.1) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from mlflow-skinny==3.10.1->mlflow==3.10.1) (1.40.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from mlflow-skinny==3.10.1->mlflow==3.10.1) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from mlflow-skinny==3.10.1->mlflow==3.10.1) (1.40.0)
# Requirement already satisfied: packaging<27 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.10.1->mlflow==3.10.1) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from mlflow-skinny==3.10.1->mlflow==3.10.1) (6.33.6)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.10.1->mlflow==3.10.1) (2.12.4)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.10.1->mlflow==3.10.1) (1.1.0)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.10.1->mlflow==3.10.1) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.10.1->mlflow==3.10.1) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from mlflow-skinny==3.10.1->mlflow==3.10.1) (0.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.10.1->mlflow==3.10.1) (4.15.0)
# Requirement already satisfied: uvicorn<1 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from mlflow-skinny==3.10.1->mlflow==3.10.1) (0.42.0)
# Requirement already satisfied: Mako in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from alembic!=1.10.0,<2->mlflow==3.10.1) (1.3.10)
# Requirement already satisfied: cffi>=2.0.0 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from cryptography<47,>=43.0.0->mlflow==3.10.1) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.1->mlflow==3.10.1) (2.49.1)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from docker<8,>=4.0.0->mlflow==3.10.1) (2.5.0)
# Requirement already satisfied: starlette>=0.46.0 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from fastapi<1->mlflow-skinny==3.10.1->mlflow==3.10.1) (1.0.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from fastapi<1->mlflow-skinny==3.10.1->mlflow==3.10.1) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from fastapi<1->mlflow-skinny==3.10.1->mlflow==3.10.1) (0.0.4)
# Requirement already satisfied: blinker>=1.9.0 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from Flask<4->mlflow==3.10.1) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from Flask<4->mlflow==3.10.1) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from Flask<4->mlflow==3.10.1) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from Flask<4->mlflow==3.10.1) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from Flask<4->mlflow==3.10.1) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.10.1->mlflow==3.10.1) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.10.1->mlflow==3.10.1) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.1->mlflow==3.10.1) (0.4.2)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from graphene<4->mlflow==3.10.1) (3.2.8)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from graphene<4->mlflow==3.10.1) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from graphene<4->mlflow==3.10.1) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.10.1->mlflow==3.10.1) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow==3.10.1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow==3.10.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow==3.10.1) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow==3.10.1) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow==3.10.1) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow==3.10.1) (3.2.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.10.1->mlflow==3.10.1) (0.61b0)
# Requirement already satisfied: pytz>=2020.1 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from pandas<3->mlflow==3.10.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from pandas<3->mlflow==3.10.1) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.10.1->mlflow==3.10.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.10.1->mlflow==3.10.1) (2.41.5)
# Requirement already satisfied: six>=1.5 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow==3.10.1) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.10.1->mlflow==3.10.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.10.1->mlflow==3.10.1) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.10.1->mlflow==3.10.1) (2025.11.12)
# Requirement already satisfied: joblib>=1.2.0 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from scikit-learn<2->mlflow==3.10.1) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from scikit-learn<2->mlflow==3.10.1) (3.5.0)
# Requirement already satisfied: prettytable>=3.9 in /Users/danielwohlgemuth/.local/lib/python3.13/site-packages (from skops<1->mlflow==3.10.1) (3.17.0)
# Requirement already satisfied: h11>=0.8 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from uvicorn<1->mlflow-skinny==3.10.1->mlflow==3.10.1) (0.16.0)
# Requirement already satisfied: pycparser in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow==3.10.1) (2.23)
# Requirement already satisfied: wcwidth in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from prettytable>=3.9->skops<1->mlflow==3.10.1) (0.2.13)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.1->mlflow==3.10.1) (0.6.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from starlette>=0.46.0->fastapi<1->mlflow-skinny==3.10.1->mlflow==3.10.1) (4.10.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/danielwohlgemuth/anaconda3/lib/python3.13/site-packages (from anyio<5,>=3.6.2->starlette>=0.46.0->fastapi<1->mlflow-skinny==3.10.1->mlflow==3.10.1) (1.3.0)

# %%
import mlflow
mlflow.set_tracking_uri("http://localhost:5000")
experiments = mlflow.search_experiments()
for exp in experiments:
    print(f"Name: {exp.name}, ID: {exp.experiment_id}")
# Out:
# Name: diabetes, ID: 2
# Name: nyc-taxi, ID: 1
# Name: Default, ID: 0

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
from sklearn.ensemble import RandomForestRegressor

# set the experiment id
mlflow.set_experiment(experiment_name="diabetes")

mlflow.autolog()
db = load_diabetes()

X_train, X_test, y_train, y_test = train_test_split(db.data, db.target)

# Create and train models.
rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3)
rf.fit(X_train, y_train)

# Use the model to make predictions on the test dataset.
predictions = rf.predict(X_test)
# Out:
# 2026/03/29 14:35:02 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/03/29 14:35:02 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '9ffe4eff68e64e61b061269f19b1b715', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2026/03/29 14:35:02 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 🏃 View run able-penguin-682 at: http://localhost:5000/#/experiments/2/runs/9ffe4eff68e64e61b061269f19b1b715
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
